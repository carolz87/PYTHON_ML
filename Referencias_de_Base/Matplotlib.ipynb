# %%
# Fazendo os imports
from matplotlib import pyplot as plt
from sklearn.datasets import make_regression

# %%
# Gerando dataset exemplo
x,y = make_regression(n_samples=200 , n_features=1, noise=30)

# %%
# Gerando e exibindo gráfico da base

plt.scatter(x,y)
plt.show()
